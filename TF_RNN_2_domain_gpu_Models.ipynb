# %%
import sys
import time
import glob
import os
import datetime
import numpy as np

import pandas as pd
import tensorflow as tf 
import tensorflow.keras.losses as kls
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt

from pathlib import Path
import pickle
from itertools import product

gpu_num = 0
tf.config.experimental.set_memory_growth(tf.config.list_physical_devices('GPU')[gpu_num], True)

# %%
main_folder_path = Path('.')
# folder_path = main_folder_path / 'Smaller_data3'
disp = False

class DataGen:
    def __init__(self, batch_size=32, dim_x = 2, dim_y = 1):
        
        self.bs = batch_size
        self.main_folder_path = Path('.')
        self.folder_path = main_folder_path / 'Smaller_data3'
                
        self.dim_x = dim_x
        self.dim_y = dim_y
        self.B_max = 0.0
        # self.B_min = 0.0
        self.seq_len = {}
        
        self.df_seq_len = pd.DataFrame(columns = ['FileName', 
                                                  'SeqLength_domain', 
                                                  'SeqLength_coil',
                                                  'SeqLength_interface'])
        
        self.get_sequence_len()
        self.df_seq_len.sort_values(by='SeqLength_domain', ascending=False, inplace=True)

        self.data_size = self.df_seq_len.shape[0]
        self.threshold_points = 500
        # self.norm_denom = self.B_max - self.B_min

        # self.max_seq_len_global = self.df_seq_len.SeqLength.max()

                
    def get_sequence_len(self):
        
        files = glob.glob1(self.folder_path, "*.csv")
        
        for csv_file in files:
            file_path = self.folder_path / csv_file
            df = pd.read_csv(file_path.absolute(), header=None)    

            if self.B_max < df[2].max():
                self.B_max = df[2].max()

            counts = df[3].value_counts()

            # 2.0    1904
            # 0.0     248
            # 1.0     113
            # Name: 3, dtype: int64

#             record = {'FileName': csv_file, 
#                       'SeqLength_domain': counts[2],
#                       'SeqLength_coil': counts[0],
#                       'SeqLength_interface': counts[1]}

#             self.df_seq_len = self.df_seq_len.append(record, ignore_index = True)

            record = pd.DataFrame({'FileName': csv_file, 
                      'SeqLength_domain': counts[2],
                      'SeqLength_coil': counts[0],
                      'SeqLength_interface': counts[1]})
            
            self.df_seq_len = pd.concat([self.df_seq_len, record])
            
    def data_feed(self, index):
        
        if (index + self.bs) >= self.df_seq_len.shape[0]:
            index = self.df_seq_len.shape[0] - self.bs - 1
        
        # batch_files = list(self.seq_len_sorted)[index : index + self.bs]
        batch_files = self.df_seq_len['FileName'].iloc[index : index + self.bs].tolist()
        
        max_seq_len_domain = max(self.df_seq_len['SeqLength_domain'].iloc[index : index + self.bs].tolist())
        if max_seq_len_domain > self.threshold_points:
            max_seq_len_domain = self.threshold_points

        max_seq_len_coil = max(self.df_seq_len['SeqLength_coil'].iloc[index : index + self.bs].tolist())
        if max_seq_len_coil > self.threshold_points:
            max_seq_len_coil = self.threshold_points

        max_seq_len_interface = max(self.df_seq_len['SeqLength_interface'].iloc[index : index + self.bs].tolist())
        if max_seq_len_interface > self.threshold_points:
            max_seq_len_interface = self.threshold_points

        max_seq_len_domain += max_seq_len_interface
        max_seq_len_coil += max_seq_len_interface

        src_len = []
        
        X_domain = np.zeros([self.bs, max_seq_len_domain, self.dim_x + 2])
        X_coil = np.zeros([self.bs, max_seq_len_coil, self.dim_x +2])
        # X_interface = np.zeros([self.bs, max_seq_len_interface, self.dim_x])

        y_domain = np.zeros([self.bs, max_seq_len_domain])
        y_coil = np.zeros([self.bs, max_seq_len_coil])
        # y_interface = np.zeros([self.bs, max_seq_len_interface])

        mask_domain = np.ones_like(X_domain)
        mask_coil = np.ones_like(X_coil)
        # mask_interface = np.ones_like(X_interface)

        # print(X.shape, y.shape)
              
        for inx, csv_file in enumerate(batch_files):

            file_path = self.folder_path / csv_file
            
            coil_radius = float(csv_file[3: csv_file.find('_ds_')])
            domain_size = float(csv_file[csv_file.find('_ds_') + 4: csv_file.find('_cm_')])
            current_magnitude = float(csv_file[csv_file.find('_cm_') + 4 : -4])

            df = pd.read_csv(file_path.absolute(), header=None)
            df.rename(columns={0: 'x', 1: 'y', 2: 'B', 3: 'mat'}, inplace=True)
                        
            ### Domain
            seq_len_domain = self.df_seq_len[self.df_seq_len['FileName'] == csv_file]['SeqLength_domain'].iloc[0]
            if seq_len_domain > self.threshold_points:
                seq_len_domain = self.threshold_points

                df_X = df.loc[df['mat'] == 2, ['x', 'y']]
                sample_inx = np.random.randint(0, df_X.shape[0], self.threshold_points)
                X_domain[inx, :seq_len_domain, :self.dim_x] = df_X.iloc[sample_inx, :].values

                df_y = df.loc[df['mat'] == 2, ['B']]
                y_domain[inx, :seq_len_domain] = df_y.iloc[sample_inx, :].values.squeeze()

                mask_domain[inx, seq_len_domain:, :] = 0
            
            else:
                X_domain[inx, :seq_len_domain, :self.dim_x] = df.loc[df['mat'] == 2, ['x', 'y']].values
                y_domain[inx, :seq_len_domain] = df.loc[df['mat'] == 2, ['B']].values.squeeze()
#                 y_domain /= self.B_max
                mask_domain[inx, seq_len_domain:, :] = 0

            ### Coil
            seq_len_coil = self.df_seq_len[self.df_seq_len['FileName'] == csv_file]['SeqLength_coil'].iloc[0]
            if seq_len_coil > self.threshold_points:
                seq_len_coil = self.threshold_points

                df_X = df.loc[df['mat'] == 0, ['x', 'y']]
                sample_inx = np.random.randint(0, df_X.shape[0], self.threshold_points)
                X_coil[inx, :seq_len_coil, :self.dim_x] = df_X.iloc[sample_inx, :].values

                df_y = df.loc[df['mat'] == 0, ['B']]
                y_coil[inx, :seq_len_coil] = df_y.iloc[sample_inx, :].values.squeeze()
                mask_coil[inx, seq_len_coil:, :] = 0
            
            else:
                X_coil[inx, :seq_len_coil, :self.dim_x] = df.loc[df['mat'] == 0, ['x', 'y']].values
                y_coil[inx, :seq_len_coil] = df.loc[df['mat'] == 0, ['B']].values.squeeze()
#                 y_coil /= self.B_max
                mask_coil[inx, seq_len_coil:, :] = 0


            ## Interface - new
            seq_len_interface = self.df_seq_len[self.df_seq_len['FileName'] == csv_file]['SeqLength_interface'].iloc[0]
            df_X = df.loc[df['mat'] == 1, ['x', 'y']]
            df_y = df.loc[df['mat'] == 1, ['B']]

            if seq_len_interface > self.threshold_points:
                seq_len_interface = self.threshold_points
                sample_inx = np.random.randint(0, df_X.shape[0], self.threshold_points)
                X_int = df_X.iloc[sample_inx, :].values
                y_int = df_y.iloc[sample_inx, :].values.squeeze()
            else:
                X_int = df.loc[df['mat'] == 1, ['x', 'y']].values
                y_int = df.loc[df['mat'] == 1, ['B']].values.squeeze()

            # Int - domain
            inx_start = seq_len_domain
            inx_stop = seq_len_domain + seq_len_interface

            X_domain[inx, inx_start:inx_stop, :self.dim_x] = X_int
            y_domain[inx, inx_start:inx_stop] = y_int.squeeze()
            y_domain[inx, :] /= self.B_max
            mask_domain[inx, inx_start:inx_stop, :] = 1

            X_domain[inx, :inx_stop, 2] = domain_size
            X_domain[inx, :inx_stop, 3] = 0

            # Int - coil
            inx_start = seq_len_coil
            inx_stop = seq_len_coil + seq_len_interface

            X_coil[inx, inx_start:inx_stop, :self.dim_x] = X_int 
            y_coil[inx, inx_start:inx_stop] =  y_int
            y_coil[inx, :] /= self.B_max
            mask_coil[inx, inx_start:inx_stop, :] = 1
            
            X_coil[inx, :inx_stop, 2] = coil_radius
            X_coil[inx, :inx_stop, 3] = current_magnitude

            src_len.append((seq_len_domain + seq_len_interface, seq_len_coil + seq_len_interface))

            masks = [mask_domain, mask_coil]
            X = [X_domain, X_coil]
            y = [y_domain, y_coil]
        
        return X, y, masks, src_len
    
    def save_plots(self, x, y, uex, upred, epoch, comment):
        
        df = pd.DataFrame({'x': x, 'y':y, 'upred': upred, 'uex': uex})
        df = df.loc[(df['x'] !=0) & (df['y'] != 0), :]
        df = df.drop_duplicates(subset=['x', 'y', 'uex'])

        fig, (ax1, ax2) = plt.subplots(1,2,figsize=(26,10))
        
        ## True Exact
        # ax2.tricontour(x, y, z, levels=20, linewidths=0.5, colors='k')
        cntr1 = ax1.tricontourf(df['x'], df['y'], df['uex'], levels=20, cmap="jet")
        
        fig.colorbar(cntr1, ax=ax1)
        # ax2.plot(x, y, 'ko', ms=3)
        # ax1.set(xlim=(-1, 1), ylim=(-1, 1))
        ax1.set_title('Exact')
        
        ## Predictions
        # ax2.tricontour(x, y, z, levels=20, linewidths=0.5, colors='k')
        cntr2 = ax2.tricontourf(df['x'], df['y'], df['upred'], levels = 20, cmap = 'jet')
        
        fig.colorbar(cntr2, ax=ax2)
        # ax2.plot(x, y, 'ko', ms=3)
        # ax2.set(xlim=(-1, 1), ylim=(-1, 1))
        ax2.set_title('Prediction')
        
        plt.subplots_adjust(hspace=0.5)
        
        file_name = f'epoch_{epoch+1}.png'
        result_folder = self.main_folder_path / 'Results_Oct_RNN' / comment
        
        if not os.path.exists(result_folder):
            os.makedirs(result_folder)
        
        plt.savefig(result_folder.absolute() / file_name, dpi=100)
        
        #plt.savefig(file_name, dpi=100)
        
        #plt.show()
        plt.close(fig)
        plt.close('all')

    def save_stats(self, dict_, epoch, comment):
       # with open('history %s' % (epoch), 'w') as outfile:
        #    outfile.write(dict_)
        result_folder = self.main_folder_path / 'Results_Oct_RNN' / comment
       
        if not os.path.exists(result_folder):
            os.makedirs(result_folder)
        file_name = f'epoch_{epoch+1}.csv'
        
        print(dict_)
        df = pd.DataFrame(dict_, index=[0])
        df.to_csv(result_folder.absolute() / file_name)
        
        
#     def save_arrays(self, x, y, uex, upred, epoch, comment):
        
#         result_folder = self.main_folder_path / 'Results_Oct_RNN_numpy' / comment
        
#         if not os.path.exists(result_folder):
#             os.makedirs(result_folder)
            
#         file_name = f'epoch_{epoch+1}_x.npy'
#         np.save(result_folder.absolute() / file_name, x)
        
#         file_name = f'epoch_{epoch+1}_y.npy'
#         np.save(result_folder.absolute() / file_name, y)
        
#         file_name = f'epoch_{epoch+1}_uex.npy'
#         np.save(result_folder.absolute() / file_name, uex)
        
#         file_name = f'epoch_{epoch+1}_upred.npy'
#         np.save(result_folder.absolute() / file_name, upred)

    def save_arrays(self, X_domain, X_coil, uex, upred_d, upred_c, epoch, comment):     
        result_folder = self.main_folder_path / 'Results_Oct_RNN_numpy' / comment
        
        if not os.path.exists(result_folder):
            os.makedirs(result_folder)
        
        file_name = f'data_epoch_{epoch+1}.pkl'
        data = {'X_domain' : X_domain, 'X_coil': X_coil, 'uex':uex, 'upred_d': upred_d, 'upred_c': upred_c}
        with open(result_folder.absolute() / file_name, 'wb') as f:
            pickle.dump(data, f)
        
        
    def save_models(self, model_domain, model_coil, epoch, comment):
        result_folder = self.main_folder_path / 'Results_Oct_RNN_models' / comment
        
        if not os.path.exists(result_folder):
            os.makedirs(result_folder)
            
        file_name = f'model_domain_epoch_{epoch+1}'
        model_domain.save(result_folder.absolute() / file_name)
        
        file_name = f'model_domain_epoch_{epoch+1}'
        model_coil.save(result_folder.absolute() / file_name)        
        
    def load_latest_models(self, epoch, comment):
        result_folder = self.main_folder_path / 'Results_Oct_RNN_models' / comment
        
        if not os.path.exists(result_folder):
            os.makedirs(result_folder)
            
        file_name = f'model_domain_epoch_{epoch+1}'
        model_domain = tf.keras.models.load_model(result_folder.absolute() / file_name)

        file_name = f'model_coil_epoch_{epoch+1}'
        model_coil = tf.keras.models.load_model(result_folder.absolute() / file_name)
        
        return model_domain, model_coil

# %%
class MyModel(tf.keras.Model):
    def __init__(self, bi=False):
        super(MyModel, self).__init__()
        self.bi = bi
       
        if self.bi == True:
            self.lstm_1 = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(
                            64, activation='tanh', 
                           dropout= 0.2, recurrent_dropout=0,
                           kernel_regularizer=l2(0.01), recurrent_regularizer=l2(0.01), bias_regularizer=l2(0.01), 
                            return_sequences= True, return_state= True))
            
            self.BN_1 = tf.keras.layers.LayerNormalization()
            
            self.lstm_2 = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(
                            32, activation='tanh', 
                           dropout= 0.2, recurrent_dropout=0, 
                           kernel_regularizer=l2(0.01), recurrent_regularizer=l2(0.01), bias_regularizer=l2(0.01),
                            return_sequences= True))
            
            self.BN_2 = tf.keras.layers.LayerNormalization()

        else:
            self.lstm_1 = tf.keras.layers.GRU(
                            64, activation='tanh', 
                            dropout= 0.2, recurrent_dropout=0, 
                            kernel_regularizer=l2(0.01), recurrent_regularizer=l2(0.01), bias_regularizer=l2(0.01),
                            return_sequences= True, return_state= True)
            
            self.BN_1 = tf.keras.layers.LayerNormalization()
            
            self.lstm_2 = tf.keras.layers.GRU(
                            32, activation='tanh', 
                            dropout= 0.2, recurrent_dropout=0, 
                            kernel_regularizer=l2(0.01), recurrent_regularizer=l2(0.01), bias_regularizer=l2(0.01),
                            return_sequences= True)
            
            self.BN_2 = tf.keras.layers.LayerNormalization()

        self.dense = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(1, activation='sigmoid'))
        
    def call(self, inputs):
        
        input1 = inputs[0]
        mask = inputs[1]

#        print(mask.shape)
        if self.bi == True:
            x, state_h, state_c = self.lstm_1(input1, mask=mask)
        else:
            x, state_h = self.lstm_1(input1, mask=mask)

        x = self.BN_1(x)
        x = self.lstm_2(x, mask=mask)
        x = self.BN_2(x)
        output = self.dense(x, mask=mask)
        return output

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
def my_training(batch, epochs, no_iters, lr, bi, train_summary_writer, comment):
    
#     mean_loss = tf.keras.metrics.Mean()
    metrics = [tf.keras.metrics.mean_absolute_error]
    model = MyModel(bi=bi)
    history = {}
    optimizer = tf.keras.optimizers.Nadam(learning_rate= lr)
    
    for epoch in range(epochs):
        start_time = time.time()
            
        for i in range(no_iters):
            
            index = np.random.randint(batch.data_size-batch.bs)
            X_d, X_c, Y_d, Y_c, mask_d, mask_c, seq_len_d, seq_len_c = batch.data_feed(index)

            # X, Y, mask, src_len = batch.data_feed(index)
#             Y_c *= 1E6
            Y_c = np.expand_dims(Y_c, axis=-1)

#             Y_d *= 1E6
            Y_d = np.expand_dims(Y_d, axis=-1)

            # mask = np.logical_not(X) # Finds all the zero values
            # returns True (before the NOT) if all the elemenst in the row are zero
            # mask = np.logical_not(np.all(mask, axis=-1))
            
            mask_d = np.logical_not(mask_d) # Finds all the zero values
            # returns True (before the NOT) if all the elemenst in the row are zero
            mask_d = np.logical_not(np.all(mask_d, axis=-1))

            mask_c = np.logical_not(mask_c) # Finds all the zero values
            # returns True (before the NOT) if all the elemenst in the row are zero
            mask_c = np.logical_not(np.all(mask_c, axis=-1))

            X_train = [X_d, mask_d]
            # print(len(X_train))
            # print('X.shape', X_d.shape)
            # print('mask.shape', mask_d.shape)
            # print('X[:,:, 0].shape', X_d[:,:, 0].shape)
            # print('X[:,:, 1].shape',X_d[:,:, 1].shape)
            # print('Y.shape', Y_d.shape)
            # print('Y_d.max', Y_d.max())
            # print('Y_d.min', Y_d.min())
            
            with tf.GradientTape() as tape:
                y_pred = model(X_train, training=True)
                # print('y_pred.shape', y_pred.shape)
                loss_ = tf.keras.losses.mean_squared_error(Y_d, y_pred)
                
            gradients = tape.gradient(loss_, model.trainable_variables)
            optimizer.apply_gradients(zip(gradients, model.trainable_variables))
            mean_loss(loss_)
            
        end_time = time.time()
        
        epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
        print('Epoch: {:02} | Time: {}m {}s\t'.format(epoch+1, epoch_mins, epoch_secs))
        try:
            print('step %s: mean loss = %s' % (epoch+1, mean_loss.result().numpy()))
            history[epoch] = mean_loss.result().numpy()
        except:
            print('step %s: mean loss = %s' % (epoch+1, mean_loss.result()))
            history[epoch] = mean_loss.result()
            
        with train_summary_writer.as_default():
            tf.summary.scalar('loss', mean_loss.result(), step=epoch)

        y_pred = model(X_train, training=False)   
        y_pred = y_pred.numpy()
        #print('y_pred.shape', y_pred.shape)
        batch.save_plots(X_d[1, :, 0], X_d[1, :, 1], Y_d[1, :,0], y_pred[1, :, 0], epoch, comment)
        
        mean_loss.reset_states()
        tf.summary.flush(train_summary_writer)
              
    # Serializing json
    #history_object = json.dumps(history, indent = 4)
    batch.save_stats(history, epoch, comment)
    #print(history_object)
        
    return history

# %%
# history = my_training(batch, epochs, no_iters, lr, bi, train_summary_writer, comment)
# my_training(batch, epochs, no_iters, lr, bi)

# %% [markdown]
# # Separate Models for different Domains

# %%
def learn(batch, epochs, no_iters, lr, bi, train_summary_writer, comment):
    
#     mean_loss_domain = tf.keras.metrics.Mean()
#     mean_loss_coil = tf.keras.metrics.Mean()

    metrics = [tf.keras.metrics.mean_absolute_error]
    model_domain = MyModel(bi=bi)
    model_coil = MyModel(bi=bi)
    
    history = {}
    
    optimizer_domain = tf.keras.optimizers.Nadam(learning_rate= lr)
    optimizer_coil = tf.keras.optimizers.Nadam(learning_rate= lr)
    
    for epoch in range(epochs):
        start_time = time.time()
        mean_loss_domain, mean_loss_coil = [], []
        plt.close('all')
            
        for i in range(no_iters):
            
            index = np.random.randint(batch.data_size-batch.bs)

            X, Y, masks, src_len = batch.data_feed(index)
            Y = [np.expand_dims(y, axis=-1) for y in Y]
            Y_domain, Y_coil = Y

            masks = [np.logical_not(mask) for mask in masks]   
            masks = [np.logical_not(np.all(mask, axis=-1)) for mask in masks]

            # X_domain, X_coil, X_interface = [[x, mask] for x, mask in zip(X, masks)]
            X_domain, X_coil = [[x, mask] for x, mask in zip(X, masks)]
            
            with tf.GradientTape(persistent=False) as tape1 :
                y_pred_domain = model_domain(X_domain, training=True)

                loss_domain = tf.keras.losses.mean_squared_error(Y_domain, y_pred_domain)

            grads1 = tape1.gradient(loss_domain, model_domain.trainable_variables)
            optimizer_domain.apply_gradients(zip(grads1, model_domain.trainable_variables))
            mean_loss_domain.append(tf.reduce_sum(loss_domain).numpy())
            
            
            del tape1
            del grads1

            with tf.GradientTape(persistent=False) as tape2 :
                y_pred_coil = model_coil(X_coil, training=True)

                loss_coil = tf.keras.losses.mean_squared_error(Y_coil, y_pred_coil)

            grads2 = tape2.gradient(loss_coil, model_coil.trainable_variables)
            optimizer_coil.apply_gradients(zip(grads2, model_coil.trainable_variables))
            
            mean_loss_coil.append(tf.reduce_sum(loss_coil).numpy())
            
            del tape2
            del grads2

#             mean_loss_domain(loss_domain)
#             mean_loss_coil(loss_coil)

#         model_coil._set_inputs(X_coil) # add this line
#         model_domain._set_inputs(X_domain) # add this line
#         batch.save_models(model_domain, model_coil, epoch, comment)
#         del model_domain
#         del model_coil
#         model_domain, model_coil = batch.load_latest_models(epoch, comment)
        
        end_time = time.time()
        
        epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
        print('Epoch: {:02} | Time: {}m {}s\t'.format(epoch+1, epoch_mins, epoch_secs))
        
        try:

            print(f'step {epoch+1}, \
            mean loss coil = {sum(mean_loss_coil) / len(mean_loss_coil)}, \
            mean loss domain = {sum(mean_loss_domain) / len(mean_loss_domain)}')
#             history[epoch] = mean_loss_coil.result().numpy() + mean_loss_domain.result().numpy()
        except:

            print(f'step {epoch+1}, \
            mean loss coil = {tf.reduce_sum(loss_coil)} \
            mean loss domain = {tf.reduce_sum(loss_domain)}')
#             mean_loss_22.result()

#         with train_summary_writer.as_default():
#             tf.summary.scalar('loss_domain', mean_loss_domain.result(), step=epoch)
#             tf.summary.scalar('loss_coil', mean_loss_coil.result(), step=epoch)
        
#         print("X_domain")
#         print(type(X_domain))
#         print(type(X_domain))
        
#         print("X_coil")
#         print(type(X_coil))
        
        X_d = X_domain[0]
        X_c = X_coil[0]
        Y_d, Y_c = Y

        X_print = np.concatenate((X_d[0], X_c[0]), axis=0) 
        Y_print = np.concatenate((Y_d[0], Y_c[0]), axis=0) 
        
        print(f'Shape: X_d:{X_d.shape}, X_c:{X_c.shape}, X_print:{X_print.shape}')
        print(f'Shape: Y_d:{Y_d.shape}, Y_c:{Y_c.shape}, Y_print:{Y_print.shape}')

        
        y_pred_domain = model_domain(X_domain, training=False)   
        y_pred_domain = y_pred_domain.numpy()
        
        y_pred_coil = model_coil(X_coil, training=False)   
        y_pred_coil = y_pred_coil.numpy()
        
        y_pred = np.concatenate((y_pred_domain[0], y_pred_coil[0]), axis=0) 
        print(f'Shape: y_pred_domain:{y_pred_domain.shape}, y_pred_coil:{y_pred_coil.shape}, y_pred:{y_pred.shape}')
        
        batch.save_plots(X_print[:, 0], X_print[:, 1], Y_print[:,0], y_pred[:, 0], epoch, comment)
        batch.save_arrays(X_domain, X_coil, Y, y_pred_domain, y_pred_coil, epoch, comment)
        
#         y_pred_all = np.concatenate((y_pred_domain, y_pred_coil), axis=0) 
#         batch.save_arrays(X_domain, X_coil, Y, y_pred_domain, y_pred_coil, epoch, comment)
        
        del y_pred_domain, y_pred_coil, y_pred
        
#         mean_loss_domain.reset_states()
#         mean_loss_coil.reset_states()
#         tf.summary.flush(train_summary_writer)
              
    # Serializing json
    #history_object = json.dumps(history, indent = 4)
#     batch.save_stats(history, epoch, comment)
    #print(history_object)

    
    return history

# %%
# batch_size = 32
# epochs = 30
# lr = 0.001
# bi = True

# main_folder_path = Path('.')
# folder_path = main_folder_path / 'Smaller_data3'

# batch = DataGen(batch_size= batch_size)
# batch.folder_path = folder_path
   
# no_iters = int(batch.df_seq_len.shape[0]/batch_size)*2

# # index = np.random.randint(batch.df_seq_len.shape[0]-batch.bs)
# # # X, Y, _, _ = batch.data_feed(index)
# # X_d, X_c, Y_d, Y_c, mask_d, mask_c, seq_len_d, seq_len_c = batch.data_feed(index)

# comment = f' App_batch_size={batch_size} lr={lr} Bi-dir={bi}'
# current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# train_log_dir = 'runs/MagApp/' + current_time + '/train' + comment
# train_summary_writer = tf.summary.create_file_writer(train_log_dir)

# %%
# learn(batch, epochs, no_iters, lr, bi)
# history = learn(batch, epochs, no_iters, lr, bi, train_summary_writer, comment)

# %%
main_folder_path = Path('.')
folder_path = main_folder_path / 'Smaller_data3'

epochs = 50   
parameters = dict(
        lr = [0.001, 0.01],
        batch_size = [16, 32],
        bi = [False, True])

param_values = [v for v in parameters.values()]

for lr, batch_size, bi in product(*param_values):
    
    comment = f' App_batch_size={batch_size} lr={lr} Bi-dir={bi}'
    current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    train_log_dir = 'runs/MagApp/' + current_time + '/train' + comment
    train_summary_writer = tf.summary.create_file_writer(train_log_dir)            
    
    batch = DataGen(batch_size= batch_size)
    batch.folder_path = folder_path     
    no_iters = int(batch.df_seq_len.shape[0]/batch_size)*2

    history = learn(batch, epochs, no_iters, lr, bi, train_summary_writer, comment)
# Out:
# Epoch: 01 | Time: 3m 47s
# step 1,             mean loss coil = 114.44039513720548,             mean loss domain = 191.62833947166402
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 02 | Time: 3m 50s
# step 2,             mean loss coil = 35.343729870842104,             mean loss domain = 117.52304032269646
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 03 | Time: 3m 49s
# step 3,             mean loss coil = 21.805736486287042,             mean loss domain = 99.33625232472139
# Shape: X_d:(16, 662, 4), X_c:(16, 420, 4), X_print:(1082, 4)
# Shape: Y_d:(16, 662, 1), Y_c:(16, 420, 1), Y_print:(1082, 1)
# Shape: y_pred_domain:(16, 662, 1), y_pred_coil:(16, 420, 1), y_pred:(1082, 1)
# Epoch: 04 | Time: 3m 48s
# step 4,             mean loss coil = 18.022980079931372,             mean loss domain = 94.06944179534912
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 05 | Time: 3m 50s
# step 5,             mean loss coil = 15.735994261216351,             mean loss domain = 92.48411055172191
# Shape: X_d:(16, 686, 4), X_c:(16, 456, 4), X_print:(1142, 4)
# Shape: Y_d:(16, 686, 1), Y_c:(16, 456, 1), Y_print:(1142, 1)
# Shape: y_pred_domain:(16, 686, 1), y_pred_coil:(16, 456, 1), y_pred:(1142, 1)
# Epoch: 06 | Time: 3m 49s
# step 6,             mean loss coil = 14.790290377038048,             mean loss domain = 93.76826268976384
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 07 | Time: 3m 49s
# step 7,             mean loss coil = 12.861464608161844,             mean loss domain = 90.16021434763536
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 08 | Time: 3m 50s
# step 8,             mean loss coil = 12.712625310382741,             mean loss domain = 86.40696346568551
# Shape: X_d:(16, 653, 4), X_c:(16, 409, 4), X_print:(1062, 4)
# Shape: Y_d:(16, 653, 1), Y_c:(16, 409, 1), Y_print:(1062, 1)
# Shape: y_pred_domain:(16, 653, 1), y_pred_coil:(16, 409, 1), y_pred:(1062, 1)
# Epoch: 09 | Time: 3m 47s
# step 9,             mean loss coil = 11.565373121098402,             mean loss domain = 88.08353253736853
# Shape: X_d:(16, 676, 4), X_c:(16, 492, 4), X_print:(1168, 4)
# Shape: Y_d:(16, 676, 1), Y_c:(16, 492, 1), Y_print:(1168, 1)
# Shape: y_pred_domain:(16, 676, 1), y_pred_coil:(16, 492, 1), y_pred:(1168, 1)
# Epoch: 10 | Time: 3m 48s
# step 10,             mean loss coil = 11.13823308058601,             mean loss domain = 91.04895731472077
# Shape: X_d:(16, 620, 4), X_c:(16, 368, 4), X_print:(988, 4)
# Shape: Y_d:(16, 620, 1), Y_c:(16, 368, 1), Y_print:(988, 1)
# Shape: y_pred_domain:(16, 620, 1), y_pred_coil:(16, 368, 1), y_pred:(988, 1)
# Epoch: 11 | Time: 3m 49s
# step 11,             mean loss coil = 11.245694713796524,             mean loss domain = 88.08650877131498
# Shape: X_d:(16, 635, 4), X_c:(16, 388, 4), X_print:(1023, 4)
# Shape: Y_d:(16, 635, 1), Y_c:(16, 388, 1), Y_print:(1023, 1)
# Shape: y_pred_domain:(16, 635, 1), y_pred_coil:(16, 388, 1), y_pred:(1023, 1)
# Epoch: 12 | Time: 3m 50s
# step 12,             mean loss coil = 10.775483863557724,             mean loss domain = 89.47121876701314
# Shape: X_d:(16, 633, 4), X_c:(16, 386, 4), X_print:(1019, 4)
# Shape: Y_d:(16, 633, 1), Y_c:(16, 386, 1), Y_print:(1019, 1)
# Shape: y_pred_domain:(16, 633, 1), y_pred_coil:(16, 386, 1), y_pred:(1019, 1)
# Epoch: 13 | Time: 3m 48s
# step 13,             mean loss coil = 10.341145571859125,             mean loss domain = 84.55408699627229
# Shape: X_d:(16, 697, 4), X_c:(16, 460, 4), X_print:(1157, 4)
# Shape: Y_d:(16, 697, 1), Y_c:(16, 460, 1), Y_print:(1157, 1)
# Shape: y_pred_domain:(16, 697, 1), y_pred_coil:(16, 460, 1), y_pred:(1157, 1)
# Epoch: 14 | Time: 3m 50s
# step 14,             mean loss coil = 10.08241308596045,             mean loss domain = 85.05053098953981
# Shape: X_d:(16, 671, 4), X_c:(16, 428, 4), X_print:(1099, 4)
# Shape: Y_d:(16, 671, 1), Y_c:(16, 428, 1), Y_print:(1099, 1)
# Shape: y_pred_domain:(16, 671, 1), y_pred_coil:(16, 428, 1), y_pred:(1099, 1)
# Epoch: 15 | Time: 3m 49s
# step 15,             mean loss coil = 9.638540346992206,             mean loss domain = 85.97103692631033
# Shape: X_d:(16, 676, 4), X_c:(16, 492, 4), X_print:(1168, 4)
# Shape: Y_d:(16, 676, 1), Y_c:(16, 492, 1), Y_print:(1168, 1)
# Shape: y_pred_domain:(16, 676, 1), y_pred_coil:(16, 492, 1), y_pred:(1168, 1)
# Epoch: 16 | Time: 3m 48s
# step 16,             mean loss coil = 9.84348178101096,             mean loss domain = 86.8131746557307
# Shape: X_d:(16, 621, 4), X_c:(16, 372, 4), X_print:(993, 4)
# Shape: Y_d:(16, 621, 1), Y_c:(16, 372, 1), Y_print:(993, 1)
# Shape: y_pred_domain:(16, 621, 1), y_pred_coil:(16, 372, 1), y_pred:(993, 1)
# Epoch: 17 | Time: 3m 48s
# step 17,             mean loss coil = 10.247075784333887,             mean loss domain = 82.56058453238585
# Shape: X_d:(16, 655, 4), X_c:(16, 411, 4), X_print:(1066, 4)
# Shape: Y_d:(16, 655, 1), Y_c:(16, 411, 1), Y_print:(1066, 1)
# Shape: y_pred_domain:(16, 655, 1), y_pred_coil:(16, 411, 1), y_pred:(1066, 1)
# Epoch: 18 | Time: 3m 49s
# step 18,             mean loss coil = 8.965467728395513,             mean loss domain = 84.64986370209067
# Shape: X_d:(16, 652, 4), X_c:(16, 409, 4), X_print:(1061, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 409, 1), Y_print:(1061, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 409, 1), y_pred:(1061, 1)
# Epoch: 19 | Time: 3m 49s
# step 19,             mean loss coil = 9.107680929535851,             mean loss domain = 84.86906920142353
# Shape: X_d:(16, 644, 4), X_c:(16, 400, 4), X_print:(1044, 4)
# Shape: Y_d:(16, 644, 1), Y_c:(16, 400, 1), Y_print:(1044, 1)
# Shape: y_pred_domain:(16, 644, 1), y_pred_coil:(16, 400, 1), y_pred:(1044, 1)
# Epoch: 20 | Time: 3m 49s
# step 20,             mean loss coil = 8.609035515848966,             mean loss domain = 85.56779574327928
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 21 | Time: 3m 49s
# step 21,             mean loss coil = 8.434593183152815,             mean loss domain = 82.69649642291553
# Shape: X_d:(16, 672, 4), X_c:(16, 428, 4), X_print:(1100, 4)
# Shape: Y_d:(16, 672, 1), Y_c:(16, 428, 1), Y_print:(1100, 1)
# Shape: y_pred_domain:(16, 672, 1), y_pred_coil:(16, 428, 1), y_pred:(1100, 1)
# Epoch: 22 | Time: 3m 49s
# step 22,             mean loss coil = 8.051145297002027,             mean loss domain = 83.63640466985855
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 23 | Time: 3m 51s
# step 23,             mean loss coil = 7.819919451991504,             mean loss domain = 85.25546149901528
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 24 | Time: 3m 50s
# step 24,             mean loss coil = 7.926854027146324,             mean loss domain = 80.74931479775331
# Shape: X_d:(16, 640, 4), X_c:(16, 396, 4), X_print:(1036, 4)
# Shape: Y_d:(16, 640, 1), Y_c:(16, 396, 1), Y_print:(1036, 1)
# Shape: y_pred_domain:(16, 640, 1), y_pred_coil:(16, 396, 1), y_pred:(1036, 1)
# Epoch: 25 | Time: 3m 51s
# step 25,             mean loss coil = 7.100272573251775,             mean loss domain = 84.57558097431367
# Shape: X_d:(16, 687, 4), X_c:(16, 443, 4), X_print:(1130, 4)
# Shape: Y_d:(16, 687, 1), Y_c:(16, 443, 1), Y_print:(1130, 1)
# Shape: y_pred_domain:(16, 687, 1), y_pred_coil:(16, 443, 1), y_pred:(1130, 1)
# Epoch: 26 | Time: 3m 52s
# step 26,             mean loss coil = 7.952004236014769,             mean loss domain = 83.05947597014075
# Shape: X_d:(16, 675, 4), X_c:(16, 434, 4), X_print:(1109, 4)
# Shape: Y_d:(16, 675, 1), Y_c:(16, 434, 1), Y_print:(1109, 1)
# Shape: y_pred_domain:(16, 675, 1), y_pred_coil:(16, 434, 1), y_pred:(1109, 1)
# Epoch: 27 | Time: 3m 49s
# step 27,             mean loss coil = 7.257248529775895,             mean loss domain = 82.33793394833324
# Shape: X_d:(16, 635, 4), X_c:(16, 388, 4), X_print:(1023, 4)
# Shape: Y_d:(16, 635, 1), Y_c:(16, 388, 1), Y_print:(1023, 1)
# Shape: y_pred_domain:(16, 635, 1), y_pred_coil:(16, 388, 1), y_pred:(1023, 1)
# Epoch: 28 | Time: 3m 51s
# step 28,             mean loss coil = 6.870302725921977,             mean loss domain = 80.51996846377531
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 29 | Time: 3m 52s
# step 29,             mean loss coil = 7.566605952971759,             mean loss domain = 79.66791983466734
# Shape: X_d:(16, 663, 4), X_c:(16, 421, 4), X_print:(1084, 4)
# Shape: Y_d:(16, 663, 1), Y_c:(16, 421, 1), Y_print:(1084, 1)
# Shape: y_pred_domain:(16, 663, 1), y_pred_coil:(16, 421, 1), y_pred:(1084, 1)
# Epoch: 30 | Time: 3m 50s
# step 30,             mean loss coil = 7.132822051405269,             mean loss domain = 77.71925302750286
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 31 | Time: 3m 52s
# step 31,             mean loss coil = 7.35407335394844,             mean loss domain = 78.71220150095894
# Shape: X_d:(16, 651, 4), X_c:(16, 407, 4), X_print:(1058, 4)
# Shape: Y_d:(16, 651, 1), Y_c:(16, 407, 1), Y_print:(1058, 1)
# Shape: y_pred_domain:(16, 651, 1), y_pred_coil:(16, 407, 1), y_pred:(1058, 1)
# Epoch: 32 | Time: 3m 50s
# step 32,             mean loss coil = 7.167250709418944,             mean loss domain = 80.44277962771329
# Shape: X_d:(16, 623, 4), X_c:(16, 374, 4), X_print:(997, 4)
# Shape: Y_d:(16, 623, 1), Y_c:(16, 374, 1), Y_print:(997, 1)
# Shape: y_pred_domain:(16, 623, 1), y_pred_coil:(16, 374, 1), y_pred:(997, 1)
# Epoch: 33 | Time: 3m 48s
# step 33,             mean loss coil = 6.841260795924753,             mean loss domain = 78.64931719570873
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 34 | Time: 3m 48s
# step 34,             mean loss coil = 6.869963873835171,             mean loss domain = 78.10040837813189
# Shape: X_d:(16, 661, 4), X_c:(16, 425, 4), X_print:(1086, 4)
# Shape: Y_d:(16, 661, 1), Y_c:(16, 425, 1), Y_print:(1086, 1)
# Shape: y_pred_domain:(16, 661, 1), y_pred_coil:(16, 425, 1), y_pred:(1086, 1)
# Epoch: 35 | Time: 3m 48s
# step 35,             mean loss coil = 6.782983736558394,             mean loss domain = 83.0888555802126
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 36 | Time: 3m 50s
# step 36,             mean loss coil = 6.545508668703191,             mean loss domain = 80.07846055056322
# Shape: X_d:(16, 652, 4), X_c:(16, 409, 4), X_print:(1061, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 409, 1), Y_print:(1061, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 409, 1), y_pred:(1061, 1)
# Epoch: 37 | Time: 3m 50s
# step 37,             mean loss coil = 6.472698348091248,             mean loss domain = 79.17933433451117
# Shape: X_d:(16, 674, 4), X_c:(16, 432, 4), X_print:(1106, 4)
# Shape: Y_d:(16, 674, 1), Y_c:(16, 432, 1), Y_print:(1106, 1)
# Shape: y_pred_domain:(16, 674, 1), y_pred_coil:(16, 432, 1), y_pred:(1106, 1)
# Epoch: 38 | Time: 3m 49s
# step 38,             mean loss coil = 6.102974331155818,             mean loss domain = 78.93891040271616
# Shape: X_d:(16, 672, 4), X_c:(16, 428, 4), X_print:(1100, 4)
# Shape: Y_d:(16, 672, 1), Y_c:(16, 428, 1), Y_print:(1100, 1)
# Shape: y_pred_domain:(16, 672, 1), y_pred_coil:(16, 428, 1), y_pred:(1100, 1)
# Epoch: 39 | Time: 3m 50s
# step 39,             mean loss coil = 6.3065108653695825,             mean loss domain = 80.3759890495137
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 40 | Time: 3m 48s
# step 40,             mean loss coil = 5.927912127525411,             mean loss domain = 81.28010328058252
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 41 | Time: 3m 53s
# step 41,             mean loss coil = 5.977032732357953,             mean loss domain = 80.96316245022942
# Shape: X_d:(16, 686, 4), X_c:(16, 456, 4), X_print:(1142, 4)
# Shape: Y_d:(16, 686, 1), Y_c:(16, 456, 1), Y_print:(1142, 1)
# Shape: y_pred_domain:(16, 686, 1), y_pred_coil:(16, 456, 1), y_pred:(1142, 1)
# Epoch: 42 | Time: 3m 49s
# step 42,             mean loss coil = 6.056715870923537,             mean loss domain = 76.44143947305527
# Shape: X_d:(16, 623, 4), X_c:(16, 374, 4), X_print:(997, 4)
# Shape: Y_d:(16, 623, 1), Y_c:(16, 374, 1), Y_print:(997, 1)
# Shape: y_pred_domain:(16, 623, 1), y_pred_coil:(16, 374, 1), y_pred:(997, 1)
# Epoch: 43 | Time: 3m 48s
# step 43,             mean loss coil = 5.759708361670295,             mean loss domain = 77.71359984249992
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 44 | Time: 3m 48s
# step 44,             mean loss coil = 5.347999705350335,             mean loss domain = 77.16849723856717
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 45 | Time: 3m 52s
# step 45,             mean loss coil = 5.655491579981411,             mean loss domain = 80.0326253488102
# Shape: X_d:(16, 656, 4), X_c:(16, 450, 4), X_print:(1106, 4)
# Shape: Y_d:(16, 656, 1), Y_c:(16, 450, 1), Y_print:(1106, 1)
# Shape: y_pred_domain:(16, 656, 1), y_pred_coil:(16, 450, 1), y_pred:(1106, 1)
# Epoch: 46 | Time: 3m 51s
# step 46,             mean loss coil = 5.940576080013724,             mean loss domain = 74.57136463226482
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 47 | Time: 3m 48s
# step 47,             mean loss coil = 5.600585590071857,             mean loss domain = 76.29629874101934
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 48 | Time: 3m 50s
# step 48,             mean loss coil = 6.175393210694114,             mean loss domain = 81.30956745912684
# Shape: X_d:(16, 649, 4), X_c:(16, 405, 4), X_print:(1054, 4)
# Shape: Y_d:(16, 649, 1), Y_c:(16, 405, 1), Y_print:(1054, 1)
# Shape: y_pred_domain:(16, 649, 1), y_pred_coil:(16, 405, 1), y_pred:(1054, 1)
# Epoch: 49 | Time: 3m 51s
# step 49,             mean loss coil = 5.5206513111604085,             mean loss domain = 77.6322631631943
# Shape: X_d:(16, 653, 4), X_c:(16, 409, 4), X_print:(1062, 4)
# Shape: Y_d:(16, 653, 1), Y_c:(16, 409, 1), Y_print:(1062, 1)
# Shape: y_pred_domain:(16, 653, 1), y_pred_coil:(16, 409, 1), y_pred:(1062, 1)
# Epoch: 50 | Time: 3m 48s
# step 50,             mean loss coil = 5.113111138821923,             mean loss domain = 75.21267196073889
# Shape: X_d:(16, 657, 4), X_c:(16, 413, 4), X_print:(1070, 4)
# Shape: Y_d:(16, 657, 1), Y_c:(16, 413, 1), Y_print:(1070, 1)
# Shape: y_pred_domain:(16, 657, 1), y_pred_coil:(16, 413, 1), y_pred:(1070, 1)
# Epoch: 01 | Time: 5m 14s
# step 1,             mean loss coil = 102.89936866479762,             mean loss domain = 183.25611348075662
# Shape: X_d:(16, 684, 4), X_c:(16, 444, 4), X_print:(1128, 4)
# Shape: Y_d:(16, 684, 1), Y_c:(16, 444, 1), Y_print:(1128, 1)
# Shape: y_pred_domain:(16, 684, 1), y_pred_coil:(16, 444, 1), y_pred:(1128, 1)
# Epoch: 02 | Time: 5m 14s
# step 2,             mean loss coil = 26.970196513568652,             mean loss domain = 99.13667870587844
# Shape: X_d:(16, 675, 4), X_c:(16, 433, 4), X_print:(1108, 4)
# Shape: Y_d:(16, 675, 1), Y_c:(16, 433, 1), Y_print:(1108, 1)
# Shape: y_pred_domain:(16, 675, 1), y_pred_coil:(16, 433, 1), y_pred:(1108, 1)
# Epoch: 03 | Time: 5m 15s
# step 3,             mean loss coil = 16.67639740074382,             mean loss domain = 88.11465038972743
# Shape: X_d:(16, 664, 4), X_c:(16, 422, 4), X_print:(1086, 4)
# Shape: Y_d:(16, 664, 1), Y_c:(16, 422, 1), Y_print:(1086, 1)
# Shape: y_pred_domain:(16, 664, 1), y_pred_coil:(16, 422, 1), y_pred:(1086, 1)
# Epoch: 04 | Time: 5m 15s
# step 4,             mean loss coil = 12.534124500611249,             mean loss domain = 83.98410826188358
# Shape: X_d:(16, 638, 4), X_c:(16, 428, 4), X_print:(1066, 4)
# Shape: Y_d:(16, 638, 1), Y_c:(16, 428, 1), Y_print:(1066, 1)
# Shape: y_pred_domain:(16, 638, 1), y_pred_coil:(16, 428, 1), y_pred:(1066, 1)
# Epoch: 05 | Time: 5m 13s
# step 5,             mean loss coil = 11.695158958435059,             mean loss domain = 77.94630780959511
# Shape: X_d:(16, 655, 4), X_c:(16, 411, 4), X_print:(1066, 4)
# Shape: Y_d:(16, 655, 1), Y_c:(16, 411, 1), Y_print:(1066, 1)
# Shape: y_pred_domain:(16, 655, 1), y_pred_coil:(16, 411, 1), y_pred:(1066, 1)
# Epoch: 06 | Time: 5m 13s
# step 6,             mean loss coil = 9.848325469914604,             mean loss domain = 76.81272062005844
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 07 | Time: 5m 13s
# step 7,             mean loss coil = 8.61164498902897,             mean loss domain = 75.52580062335825
# Shape: X_d:(16, 653, 4), X_c:(16, 409, 4), X_print:(1062, 4)
# Shape: Y_d:(16, 653, 1), Y_c:(16, 409, 1), Y_print:(1062, 1)
# Shape: y_pred_domain:(16, 653, 1), y_pred_coil:(16, 409, 1), y_pred:(1062, 1)
# Epoch: 08 | Time: 5m 14s
# step 8,             mean loss coil = 7.564547160411264,             mean loss domain = 76.268137253542
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 09 | Time: 5m 13s
# step 9,             mean loss coil = 7.061276354891731,             mean loss domain = 73.90886425334502
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 10 | Time: 5m 13s
# step 10,             mean loss coil = 6.056593866909251,             mean loss domain = 70.91232243196212
# Shape: X_d:(16, 622, 4), X_c:(16, 373, 4), X_print:(995, 4)
# Shape: Y_d:(16, 622, 1), Y_c:(16, 373, 1), Y_print:(995, 1)
# Shape: y_pred_domain:(16, 622, 1), y_pred_coil:(16, 373, 1), y_pred:(995, 1)
# Epoch: 11 | Time: 5m 17s
# step 11,             mean loss coil = 5.7401948995131225,             mean loss domain = 75.38264509700836
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 12 | Time: 5m 14s
# step 12,             mean loss coil = 5.204582668243245,             mean loss domain = 71.9472461792237
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 13 | Time: 5m 18s
# step 13,             mean loss coil = 4.3393754315248785,             mean loss domain = 71.75187534699465
# Shape: X_d:(16, 651, 4), X_c:(16, 407, 4), X_print:(1058, 4)
# Shape: Y_d:(16, 651, 1), Y_c:(16, 407, 1), Y_print:(1058, 1)
# Shape: y_pred_domain:(16, 651, 1), y_pred_coil:(16, 407, 1), y_pred:(1058, 1)
# Epoch: 14 | Time: 5m 13s
# step 14,             mean loss coil = 4.101151607093964,             mean loss domain = 72.24416856714748
# Shape: X_d:(16, 623, 4), X_c:(16, 374, 4), X_print:(997, 4)
# Shape: Y_d:(16, 623, 1), Y_c:(16, 374, 1), Y_print:(997, 1)
# Shape: y_pred_domain:(16, 623, 1), y_pred_coil:(16, 374, 1), y_pred:(997, 1)
# Epoch: 15 | Time: 5m 15s
# step 15,             mean loss coil = 3.982578221489401,             mean loss domain = 71.74023581826113
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 16 | Time: 5m 14s
# step 16,             mean loss coil = 3.6025810047266953,             mean loss domain = 71.9856965376094
# Shape: X_d:(16, 673, 4), X_c:(16, 432, 4), X_print:(1105, 4)
# Shape: Y_d:(16, 673, 1), Y_c:(16, 432, 1), Y_print:(1105, 1)
# Shape: y_pred_domain:(16, 673, 1), y_pred_coil:(16, 432, 1), y_pred:(1105, 1)
# Epoch: 17 | Time: 5m 14s
# step 17,             mean loss coil = 3.0331887054570856,             mean loss domain = 72.3057791485506
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 18 | Time: 5m 14s
# step 18,             mean loss coil = 3.193256903937794,             mean loss domain = 73.51820460232821
# Shape: X_d:(16, 647, 4), X_c:(16, 403, 4), X_print:(1050, 4)
# Shape: Y_d:(16, 647, 1), Y_c:(16, 403, 1), Y_print:(1050, 1)
# Shape: y_pred_domain:(16, 647, 1), y_pred_coil:(16, 403, 1), y_pred:(1050, 1)
# Epoch: 19 | Time: 5m 16s
# step 19,             mean loss coil = 3.050827731263829,             mean loss domain = 71.05905565221042
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 20 | Time: 5m 16s
# step 20,             mean loss coil = 2.83041060480842,             mean loss domain = 71.3118224475473
# Shape: X_d:(16, 694, 4), X_c:(16, 452, 4), X_print:(1146, 4)
# Shape: Y_d:(16, 694, 1), Y_c:(16, 452, 1), Y_print:(1146, 1)
# Shape: y_pred_domain:(16, 694, 1), y_pred_coil:(16, 452, 1), y_pred:(1146, 1)
# Epoch: 21 | Time: 5m 12s
# step 21,             mean loss coil = 2.468833801580623,             mean loss domain = 72.57962460951371
# Shape: X_d:(16, 692, 4), X_c:(16, 451, 4), X_print:(1143, 4)
# Shape: Y_d:(16, 692, 1), Y_c:(16, 451, 1), Y_print:(1143, 1)
# Shape: y_pred_domain:(16, 692, 1), y_pred_coil:(16, 451, 1), y_pred:(1143, 1)
# Epoch: 22 | Time: 5m 13s
# step 22,             mean loss coil = 2.455476327375932,             mean loss domain = 70.5492892035826
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 23 | Time: 5m 15s
# step 23,             mean loss coil = 2.3784070501034273,             mean loss domain = 70.93041837151675
# Shape: X_d:(16, 652, 4), X_c:(16, 409, 4), X_print:(1061, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 409, 1), Y_print:(1061, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 409, 1), y_pred:(1061, 1)
# Epoch: 24 | Time: 5m 13s
# step 24,             mean loss coil = 2.3372167855660546,             mean loss domain = 70.4935448437451
# Shape: X_d:(16, 677, 4), X_c:(16, 436, 4), X_print:(1113, 4)
# Shape: Y_d:(16, 677, 1), Y_c:(16, 436, 1), Y_print:(1113, 1)
# Shape: y_pred_domain:(16, 677, 1), y_pred_coil:(16, 436, 1), y_pred:(1113, 1)
# Epoch: 25 | Time: 5m 14s
# step 25,             mean loss coil = 2.028330531987277,             mean loss domain = 69.92159299799465
# Shape: X_d:(16, 684, 4), X_c:(16, 444, 4), X_print:(1128, 4)
# Shape: Y_d:(16, 684, 1), Y_c:(16, 444, 1), Y_print:(1128, 1)
# Shape: y_pred_domain:(16, 684, 1), y_pred_coil:(16, 444, 1), y_pred:(1128, 1)
# Epoch: 26 | Time: 5m 15s
# step 26,             mean loss coil = 1.9779791729972962,             mean loss domain = 71.06240680765978
# Shape: X_d:(16, 701, 4), X_c:(16, 461, 4), X_print:(1162, 4)
# Shape: Y_d:(16, 701, 1), Y_c:(16, 461, 1), Y_print:(1162, 1)
# Shape: y_pred_domain:(16, 701, 1), y_pred_coil:(16, 461, 1), y_pred:(1162, 1)
# Epoch: 27 | Time: 5m 15s
# step 27,             mean loss coil = 2.112913792385137,             mean loss domain = 72.39492587227235
# Shape: X_d:(16, 686, 4), X_c:(16, 456, 4), X_print:(1142, 4)
# Shape: Y_d:(16, 686, 1), Y_c:(16, 456, 1), Y_print:(1142, 1)
# Shape: y_pred_domain:(16, 686, 1), y_pred_coil:(16, 456, 1), y_pred:(1142, 1)
# Epoch: 28 | Time: 5m 14s
# step 28,             mean loss coil = 1.9445700874143743,             mean loss domain = 68.5763839935874
# Shape: X_d:(16, 652, 4), X_c:(16, 409, 4), X_print:(1061, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 409, 1), Y_print:(1061, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 409, 1), y_pred:(1061, 1)
# Epoch: 29 | Time: 5m 18s
# step 29,             mean loss coil = 1.8503316270316985,             mean loss domain = 73.7018418006081
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 30 | Time: 5m 14s
# step 30,             mean loss coil = 1.7664975924766,             mean loss domain = 70.27163515753925
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 31 | Time: 5m 16s
# step 31,             mean loss coil = 1.8024653257692562,             mean loss domain = 70.90362087035561
# Shape: X_d:(16, 690, 4), X_c:(16, 449, 4), X_print:(1139, 4)
# Shape: Y_d:(16, 690, 1), Y_c:(16, 449, 1), Y_print:(1139, 1)
# Shape: y_pred_domain:(16, 690, 1), y_pred_coil:(16, 449, 1), y_pred:(1139, 1)
# Epoch: 32 | Time: 5m 16s
# step 32,             mean loss coil = 1.8269456105436233,             mean loss domain = 71.60861430703638
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 33 | Time: 5m 13s
# step 33,             mean loss coil = 1.6730775021136126,             mean loss domain = 70.21344148666464
# Shape: X_d:(16, 686, 4), X_c:(16, 456, 4), X_print:(1142, 4)
# Shape: Y_d:(16, 686, 1), Y_c:(16, 456, 1), Y_print:(1142, 1)
# Shape: y_pred_domain:(16, 686, 1), y_pred_coil:(16, 456, 1), y_pred:(1142, 1)
# Epoch: 34 | Time: 5m 13s
# step 34,             mean loss coil = 1.5958562139521308,             mean loss domain = 69.88585071767716
# Shape: X_d:(16, 673, 4), X_c:(16, 429, 4), X_print:(1102, 4)
# Shape: Y_d:(16, 673, 1), Y_c:(16, 429, 1), Y_print:(1102, 1)
# Shape: y_pred_domain:(16, 673, 1), y_pred_coil:(16, 429, 1), y_pred:(1102, 1)
# Epoch: 35 | Time: 5m 16s
# step 35,             mean loss coil = 1.42185245820864,             mean loss domain = 70.89597207339689
# Shape: X_d:(16, 686, 4), X_c:(16, 456, 4), X_print:(1142, 4)
# Shape: Y_d:(16, 686, 1), Y_c:(16, 456, 1), Y_print:(1142, 1)
# Shape: y_pred_domain:(16, 686, 1), y_pred_coil:(16, 456, 1), y_pred:(1142, 1)
# Epoch: 36 | Time: 5m 14s
# step 36,             mean loss coil = 1.5885228262068753,             mean loss domain = 67.50527003742157
# Shape: X_d:(16, 670, 4), X_c:(16, 427, 4), X_print:(1097, 4)
# Shape: Y_d:(16, 670, 1), Y_c:(16, 427, 1), Y_print:(1097, 1)
# Shape: y_pred_domain:(16, 670, 1), y_pred_coil:(16, 427, 1), y_pred:(1097, 1)
# Epoch: 37 | Time: 5m 16s
# step 37,             mean loss coil = 1.4681572611717617,             mean loss domain = 71.86254791269965
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 38 | Time: 5m 20s
# step 38,             mean loss coil = 1.4454834382323658,             mean loss domain = 69.83434815585295
# Shape: X_d:(16, 673, 4), X_c:(16, 429, 4), X_print:(1102, 4)
# Shape: Y_d:(16, 673, 1), Y_c:(16, 429, 1), Y_print:(1102, 1)
# Shape: y_pred_domain:(16, 673, 1), y_pred_coil:(16, 429, 1), y_pred:(1102, 1)
# Epoch: 39 | Time: 5m 17s
# step 39,             mean loss coil = 1.2659140900175838,             mean loss domain = 65.9414028228923
# Shape: X_d:(16, 651, 4), X_c:(16, 407, 4), X_print:(1058, 4)
# Shape: Y_d:(16, 651, 1), Y_c:(16, 407, 1), Y_print:(1058, 1)
# Shape: y_pred_domain:(16, 651, 1), y_pred_coil:(16, 407, 1), y_pred:(1058, 1)
# Epoch: 40 | Time: 5m 18s
# step 40,             mean loss coil = 1.2729521286200711,             mean loss domain = 70.27457318331469
# Shape: X_d:(16, 656, 4), X_c:(16, 450, 4), X_print:(1106, 4)
# Shape: Y_d:(16, 656, 1), Y_c:(16, 450, 1), Y_print:(1106, 1)
# Shape: y_pred_domain:(16, 656, 1), y_pred_coil:(16, 450, 1), y_pred:(1106, 1)
# Epoch: 41 | Time: 5m 20s
# step 41,             mean loss coil = 1.243816953212182,             mean loss domain = 67.33419892367195
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 42 | Time: 5m 20s
# step 42,             mean loss coil = 1.2542685667540938,             mean loss domain = 68.65097694090981
# Shape: X_d:(16, 636, 4), X_c:(16, 388, 4), X_print:(1024, 4)
# Shape: Y_d:(16, 636, 1), Y_c:(16, 388, 1), Y_print:(1024, 1)
# Shape: y_pred_domain:(16, 636, 1), y_pred_coil:(16, 388, 1), y_pred:(1024, 1)
# Epoch: 43 | Time: 5m 17s
# step 43,             mean loss coil = 1.1203224572905883,             mean loss domain = 66.90566623657145
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 44 | Time: 5m 15s
# step 44,             mean loss coil = 1.292015661052204,             mean loss domain = 69.9721731043117
# Shape: X_d:(16, 651, 4), X_c:(16, 407, 4), X_print:(1058, 4)
# Shape: Y_d:(16, 651, 1), Y_c:(16, 407, 1), Y_print:(1058, 1)
# Shape: y_pred_domain:(16, 651, 1), y_pred_coil:(16, 407, 1), y_pred:(1058, 1)
# Epoch: 45 | Time: 5m 17s
# step 45,             mean loss coil = 1.2038809370229588,             mean loss domain = 67.73837844063254
# Shape: X_d:(16, 656, 4), X_c:(16, 412, 4), X_print:(1068, 4)
# Shape: Y_d:(16, 656, 1), Y_c:(16, 412, 1), Y_print:(1068, 1)
# Shape: y_pred_domain:(16, 656, 1), y_pred_coil:(16, 412, 1), y_pred:(1068, 1)
# Epoch: 46 | Time: 5m 18s
# step 46,             mean loss coil = 1.1463847287835922,             mean loss domain = 69.39310905385145
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 47 | Time: 5m 20s
# step 47,             mean loss coil = 1.1547009290699015,             mean loss domain = 69.16931065646085
# Shape: X_d:(16, 644, 4), X_c:(16, 400, 4), X_print:(1044, 4)
# Shape: Y_d:(16, 644, 1), Y_c:(16, 400, 1), Y_print:(1044, 1)
# Shape: y_pred_domain:(16, 644, 1), y_pred_coil:(16, 400, 1), y_pred:(1044, 1)
# Epoch: 48 | Time: 5m 19s
# step 48,             mean loss coil = 1.042271659973471,             mean loss domain = 68.50372482238606
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 49 | Time: 5m 20s
# step 49,             mean loss coil = 0.9621103056930603,             mean loss domain = 69.59016073451323
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 50 | Time: 5m 20s
# step 50,             mean loss coil = 0.9183782645486256,             mean loss domain = 67.91646722293792
# Shape: X_d:(16, 639, 4), X_c:(16, 392, 4), X_print:(1031, 4)
# Shape: Y_d:(16, 639, 1), Y_c:(16, 392, 1), Y_print:(1031, 1)
# Shape: y_pred_domain:(16, 639, 1), y_pred_coil:(16, 392, 1), y_pred:(1031, 1)
# Epoch: 01 | Time: 2m 51s
# step 1,             mean loss coil = 328.52461107315554,             mean loss domain = 364.27479692684705
# Shape: X_d:(32, 662, 4), X_c:(32, 420, 4), X_print:(1082, 4)
# Shape: Y_d:(32, 662, 1), Y_c:(32, 420, 1), Y_print:(1082, 1)
# Shape: y_pred_domain:(32, 662, 1), y_pred_coil:(32, 420, 1), y_pred:(1082, 1)
# Epoch: 02 | Time: 2m 52s
# step 2,             mean loss coil = 128.14744523776474,             mean loss domain = 236.62700739214498
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
# Epoch: 03 | Time: 2m 50s
# step 3,             mean loss coil = 73.85567637925507,             mean loss domain = 208.5044851405646
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
# Epoch: 04 | Time: 2m 52s
# step 4,             mean loss coil = 54.3973438765413,             mean loss domain = 188.8240727250294
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
# Epoch: 05 | Time: 2m 51s
# step 5,             mean loss coil = 43.473404074227936,             mean loss domain = 183.23503559891896
# Shape: X_d:(32, 655, 4), X_c:(32, 411, 4), X_print:(1066, 4)
# Shape: Y_d:(32, 655, 1), Y_c:(32, 411, 1), Y_print:(1066, 1)
# Shape: y_pred_domain:(32, 655, 1), y_pred_coil:(32, 411, 1), y_pred:(1066, 1)
# Epoch: 06 | Time: 2m 53s
# step 6,             mean loss coil = 36.70371816747932,             mean loss domain = 185.7595934303858
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
# Epoch: 07 | Time: 2m 52s
# step 7,             mean loss coil = 34.23266022436081,             mean loss domain = 178.79830007655647
# Shape: X_d:(32, 655, 4), X_c:(32, 411, 4), X_print:(1066, 4)
# Shape: Y_d:(32, 655, 1), Y_c:(32, 411, 1), Y_print:(1066, 1)
# Shape: y_pred_domain:(32, 655, 1), y_pred_coil:(32, 411, 1), y_pred:(1066, 1)
# Epoch: 08 | Time: 2m 46s
# step 8,             mean loss coil = 32.07746664170296,             mean loss domain = 181.71394346093618
# Shape: X_d:(32, 687, 4), X_c:(32, 443, 4), X_print:(1130, 4)
# Shape: Y_d:(32, 687, 1), Y_c:(32, 443, 1), Y_print:(1130, 1)
# Shape: y_pred_domain:(32, 687, 1), y_pred_coil:(32, 443, 1), y_pred:(1130, 1)
# Epoch: 09 | Time: 2m 48s
# step 9,             mean loss coil = 31.68308716435586,             mean loss domain = 176.65456341158958
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
# Epoch: 10 | Time: 2m 51s
# step 10,             mean loss coil = 26.72076113377848,             mean loss domain = 181.6452473876297
# Shape: X_d:(32, 653, 4), X_c:(32, 409, 4), X_print:(1062, 4)
# Shape: Y_d:(32, 653, 1), Y_c:(32, 409, 1), Y_print:(1062, 1)
# Shape: y_pred_domain:(32, 653, 1), y_pred_coil:(32, 409, 1), y_pred:(1062, 1)
# Epoch: 11 | Time: 2m 52s
# step 11,             mean loss coil = 29.34509793917338,             mean loss domain = 179.52202177560457
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
# Epoch: 12 | Time: 2m 49s
# step 12,             mean loss coil = 28.248712237163257,             mean loss domain = 172.96389030128398
# Shape: X_d:(32, 633, 4), X_c:(32, 386, 4), X_print:(1019, 4)
# Shape: Y_d:(32, 633, 1), Y_c:(32, 386, 1), Y_print:(1019, 1)
# Shape: y_pred_domain:(32, 633, 1), y_pred_coil:(32, 386, 1), y_pred:(1019, 1)
# Epoch: 13 | Time: 2m 50s
# step 13,             mean loss coil = 24.48108611824692,             mean loss domain = 181.11511931880827
# Shape: X_d:(32, 686, 4), X_c:(32, 456, 4), X_print:(1142, 4)
# Shape: Y_d:(32, 686, 1), Y_c:(32, 456, 1), Y_print:(1142, 1)
# Shape: y_pred_domain:(32, 686, 1), y_pred_coil:(32, 456, 1), y_pred:(1142, 1)
# Epoch: 14 | Time: 2m 53s
# step 14,             mean loss coil = 26.60303061239181,             mean loss domain = 168.12761243184408
# Shape: X_d:(32, 653, 4), X_c:(32, 409, 4), X_print:(1062, 4)
# Shape: Y_d:(32, 653, 1), Y_c:(32, 409, 1), Y_print:(1062, 1)
# Shape: y_pred_domain:(32, 653, 1), y_pred_coil:(32, 409, 1), y_pred:(1062, 1)
# Epoch: 15 | Time: 2m 53s
# step 15,             mean loss coil = 24.797630004985358,             mean loss domain = 170.99061637796382
# Shape: X_d:(32, 664, 4), X_c:(32, 458, 4), X_print:(1122, 4)
# Shape: Y_d:(32, 664, 1), Y_c:(32, 458, 1), Y_print:(1122, 1)
# Shape: y_pred_domain:(32, 664, 1), y_pred_coil:(32, 458, 1), y_pred:(1122, 1)
# Epoch: 16 | Time: 2m 51s
# step 16,             mean loss coil = 24.104489511059178,             mean loss domain = 170.41488653613675
# Shape: X_d:(32, 685, 4), X_c:(32, 445, 4), X_print:(1130, 4)
# Shape: Y_d:(32, 685, 1), Y_c:(32, 445, 1), Y_print:(1130, 1)
# Shape: y_pred_domain:(32, 685, 1), y_pred_coil:(32, 445, 1), y_pred:(1130, 1)
# Epoch: 17 | Time: 2m 54s
# step 17,             mean loss coil = 23.660022622795516,             mean loss domain = 178.7810291577411
# Shape: X_d:(32, 656, 4), X_c:(32, 412, 4), X_print:(1068, 4)
# Shape: Y_d:(32, 656, 1), Y_c:(32, 412, 1), Y_print:(1068, 1)
# Shape: y_pred_domain:(32, 656, 1), y_pred_coil:(32, 412, 1), y_pred:(1068, 1)
# Epoch: 18 | Time: 2m 51s
# step 18,             mean loss coil = 22.99815467096144,             mean loss domain = 167.54507743671377
# Shape: X_d:(32, 703, 4), X_c:(32, 463, 4), X_print:(1166, 4)
# Shape: Y_d:(32, 703, 1), Y_c:(32, 463, 1), Y_print:(1166, 1)
# Shape: y_pred_domain:(32, 703, 1), y_pred_coil:(32, 463, 1), y_pred:(1166, 1)
# Epoch: 19 | Time: 2m 51s
# step 19,             mean loss coil = 23.74831428835469,             mean loss domain = 167.9598142357283
# Shape: X_d:(32, 672, 4), X_c:(32, 431, 4), X_print:(1103, 4)
# Shape: Y_d:(32, 672, 1), Y_c:(32, 431, 1), Y_print:(1103, 1)
# Shape: y_pred_domain:(32, 672, 1), y_pred_coil:(32, 431, 1), y_pred:(1103, 1)
# Epoch: 20 | Time: 2m 53s
# step 20,             mean loss coil = 21.99145254268441,             mean loss domain = 173.4940649873467
# Shape: X_d:(32, 656, 4), X_c:(32, 412, 4), X_print:(1068, 4)
# Shape: Y_d:(32, 656, 1), Y_c:(32, 412, 1), Y_print:(1068, 1)
# Shape: y_pred_domain:(32, 656, 1), y_pred_coil:(32, 412, 1), y_pred:(1068, 1)
# Epoch: 21 | Time: 2m 51s
# step 21,             mean loss coil = 20.38455102776968,             mean loss domain = 169.41133804731473
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
# Epoch: 22 | Time: 2m 52s
# step 22,             mean loss coil = 20.828120795629356,             mean loss domain = 165.27272052149618
# Shape: X_d:(32, 653, 4), X_c:(32, 410, 4), X_print:(1063, 4)
# Shape: Y_d:(32, 653, 1), Y_c:(32, 410, 1), Y_print:(1063, 1)
# Shape: y_pred_domain:(32, 653, 1), y_pred_coil:(32, 410, 1), y_pred:(1063, 1)
# Epoch: 23 | Time: 2m 52s
# step 23,             mean loss coil = 21.787531957831433,             mean loss domain = 172.56704414531748
# Shape: X_d:(32, 681, 4), X_c:(32, 438, 4), X_print:(1119, 4)
# Shape: Y_d:(32, 681, 1), Y_c:(32, 438, 1), Y_print:(1119, 1)
# Shape: y_pred_domain:(32, 681, 1), y_pred_coil:(32, 438, 1), y_pred:(1119, 1)
# Epoch: 24 | Time: 2m 51s
# step 24,             mean loss coil = 20.536117702402095,             mean loss domain = 166.68422563614385
# Shape: X_d:(32, 686, 4), X_c:(32, 456, 4), X_print:(1142, 4)
# Shape: Y_d:(32, 686, 1), Y_c:(32, 456, 1), Y_print:(1142, 1)
# Shape: y_pred_domain:(32, 686, 1), y_pred_coil:(32, 456, 1), y_pred:(1142, 1)
# Epoch: 25 | Time: 2m 52s
# step 25,             mean loss coil = 22.36528755003406,             mean loss domain = 169.53629571648054
# Shape: X_d:(32, 657, 4), X_c:(32, 418, 4), X_print:(1075, 4)
# Shape: Y_d:(32, 657, 1), Y_c:(32, 418, 1), Y_print:(1075, 1)
# Shape: y_pred_domain:(32, 657, 1), y_pred_coil:(32, 418, 1), y_pred:(1075, 1)
# Epoch: 26 | Time: 2m 51s
# step 26,             mean loss coil = 19.56322111750162,             mean loss domain = 165.02474062929872
# Shape: X_d:(32, 657, 4), X_c:(32, 418, 4), X_print:(1075, 4)
# Shape: Y_d:(32, 657, 1), Y_c:(32, 418, 1), Y_print:(1075, 1)
# Shape: y_pred_domain:(32, 657, 1), y_pred_coil:(32, 418, 1), y_pred:(1075, 1)
# Epoch: 27 | Time: 2m 53s
# step 27,             mean loss coil = 20.573424841768,             mean loss domain = 162.99466239765127
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
# Epoch: 28 | Time: 2m 52s
# step 28,             mean loss coil = 18.988883515839937,             mean loss domain = 167.63049345119026
# Shape: X_d:(32, 656, 4), X_c:(32, 412, 4), X_print:(1068, 4)
# Shape: Y_d:(32, 656, 1), Y_c:(32, 412, 1), Y_print:(1068, 1)
# Shape: y_pred_domain:(32, 656, 1), y_pred_coil:(32, 412, 1), y_pred:(1068, 1)
# Epoch: 29 | Time: 2m 53s
# step 29,             mean loss coil = 18.86135421517075,             mean loss domain = 165.8130635907573
# Shape: X_d:(32, 677, 4), X_c:(32, 436, 4), X_print:(1113, 4)
# Shape: Y_d:(32, 677, 1), Y_c:(32, 436, 1), Y_print:(1113, 1)
# Shape: y_pred_domain:(32, 677, 1), y_pred_coil:(32, 436, 1), y_pred:(1113, 1)
# Epoch: 30 | Time: 2m 52s
# step 30,             mean loss coil = 17.769576404684333,             mean loss domain = 163.62668365560552
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
# Epoch: 31 | Time: 2m 53s
# step 31,             mean loss coil = 19.463620639616444,             mean loss domain = 160.74414835694014
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
# Epoch: 32 | Time: 2m 50s
# step 32,             mean loss coil = 17.741294255820655,             mean loss domain = 161.03093294943534
# Shape: X_d:(32, 703, 4), X_c:(32, 463, 4), X_print:(1166, 4)
# Shape: Y_d:(32, 703, 1), Y_c:(32, 463, 1), Y_print:(1166, 1)
# Shape: y_pred_domain:(32, 703, 1), y_pred_coil:(32, 463, 1), y_pred:(1166, 1)
# Epoch: 33 | Time: 2m 52s
# step 33,             mean loss coil = 16.72227652867635,             mean loss domain = 154.7085796684347
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
# Epoch: 34 | Time: 2m 51s
# step 34,             mean loss coil = 18.263046172357374,             mean loss domain = 157.23096859839654
# Shape: X_d:(32, 686, 4), X_c:(32, 456, 4), X_print:(1142, 4)
# Shape: Y_d:(32, 686, 1), Y_c:(32, 456, 1), Y_print:(1142, 1)
# Shape: y_pred_domain:(32, 686, 1), y_pred_coil:(32, 456, 1), y_pred:(1142, 1)
# Epoch: 35 | Time: 2m 49s
# step 35,             mean loss coil = 15.221494060690684,             mean loss domain = 156.07129336941628
# Shape: X_d:(32, 697, 4), X_c:(32, 466, 4), X_print:(1163, 4)
# Shape: Y_d:(32, 697, 1), Y_c:(32, 466, 1), Y_print:(1163, 1)
# Shape: y_pred_domain:(32, 697, 1), y_pred_coil:(32, 466, 1), y_pred:(1163, 1)
# Epoch: 36 | Time: 2m 51s
# step 36,             mean loss coil = 18.62271934811787,             mean loss domain = 152.36879822515672
# Shape: X_d:(32, 686, 4), X_c:(32, 456, 4), X_print:(1142, 4)
# Shape: Y_d:(32, 686, 1), Y_c:(32, 456, 1), Y_print:(1142, 1)
# Shape: y_pred_domain:(32, 686, 1), y_pred_coil:(32, 456, 1), y_pred:(1142, 1)
# Epoch: 37 | Time: 2m 51s
# step 37,             mean loss coil = 15.976287027840973,             mean loss domain = 154.85613892668036
# Shape: X_d:(32, 673, 4), X_c:(32, 432, 4), X_print:(1105, 4)
# Shape: Y_d:(32, 673, 1), Y_c:(32, 432, 1), Y_print:(1105, 1)
# Shape: y_pred_domain:(32, 673, 1), y_pred_coil:(32, 432, 1), y_pred:(1105, 1)
# Epoch: 38 | Time: 2m 50s
# step 38,             mean loss coil = 17.227974801935176,             mean loss domain = 157.52937770146195
# Shape: X_d:(32, 688, 4), X_c:(32, 512, 4), X_print:(1200, 4)
# Shape: Y_d:(32, 688, 1), Y_c:(32, 512, 1), Y_print:(1200, 1)
# Shape: y_pred_domain:(32, 688, 1), y_pred_coil:(32, 512, 1), y_pred:(1200, 1)
# Epoch: 39 | Time: 2m 51s
# step 39,             mean loss coil = 14.659639021401764,             mean loss domain = 158.4702208939419
# Shape: X_d:(32, 683, 4), X_c:(32, 440, 4), X_print:(1123, 4)
# Shape: Y_d:(32, 683, 1), Y_c:(32, 440, 1), Y_print:(1123, 1)
# Shape: y_pred_domain:(32, 683, 1), y_pred_coil:(32, 440, 1), y_pred:(1123, 1)
# Epoch: 40 | Time: 2m 51s
# step 40,             mean loss coil = 16.361516135995107,             mean loss domain = 158.9343115283597
# Shape: X_d:(32, 688, 4), X_c:(32, 512, 4), X_print:(1200, 4)
# Shape: Y_d:(32, 688, 1), Y_c:(32, 512, 1), Y_print:(1200, 1)
# Shape: y_pred_domain:(32, 688, 1), y_pred_coil:(32, 512, 1), y_pred:(1200, 1)
# Epoch: 41 | Time: 2m 50s
# step 41,             mean loss coil = 15.59073115420598,             mean loss domain = 157.9846114497031
# Shape: X_d:(32, 682, 4), X_c:(32, 462, 4), X_print:(1144, 4)
# Shape: Y_d:(32, 682, 1), Y_c:(32, 462, 1), Y_print:(1144, 1)
# Shape: y_pred_domain:(32, 682, 1), y_pred_coil:(32, 462, 1), y_pred:(1144, 1)
# Epoch: 42 | Time: 2m 51s
# step 42,             mean loss coil = 16.525898510409938,             mean loss domain = 157.05799894435432
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
# Epoch: 43 | Time: 2m 50s
# step 43,             mean loss coil = 16.660742593067948,             mean loss domain = 159.25561232207923
# Shape: X_d:(32, 673, 4), X_c:(32, 429, 4), X_print:(1102, 4)
# Shape: Y_d:(32, 673, 1), Y_c:(32, 429, 1), Y_print:(1102, 1)
# Shape: y_pred_domain:(32, 673, 1), y_pred_coil:(32, 429, 1), y_pred:(1102, 1)
# Epoch: 44 | Time: 3m 9s
# step 44,             mean loss coil = 14.381792745282572,             mean loss domain = 153.25802524115448
# Shape: X_d:(32, 656, 4), X_c:(32, 412, 4), X_print:(1068, 4)
# Shape: Y_d:(32, 656, 1), Y_c:(32, 412, 1), Y_print:(1068, 1)
# Shape: y_pred_domain:(32, 656, 1), y_pred_coil:(32, 412, 1), y_pred:(1068, 1)
# Epoch: 45 | Time: 3m 37s
# step 45,             mean loss coil = 13.621296396819494,             mean loss domain = 152.28590963220083
# ...
# Epoch: 38 | Time: 5m 35s
# step 38,             mean loss coil = 732.5690292113605,             mean loss domain = 340.4226988114138
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 39 | Time: 5m 34s
# step 39,             mean loss coil = 684.8514420208446,             mean loss domain = 319.76919468966395
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 40 | Time: 5m 36s
# step 40,             mean loss coil = 696.8918432347915,             mean loss domain = 325.0461317664162
# Shape: X_d:(16, 686, 4), X_c:(16, 456, 4), X_print:(1142, 4)
# Shape: Y_d:(16, 686, 1), Y_c:(16, 456, 1), Y_print:(1142, 1)
# Shape: y_pred_domain:(16, 686, 1), y_pred_coil:(16, 456, 1), y_pred:(1142, 1)
# Epoch: 41 | Time: 5m 35s
# step 41,             mean loss coil = 709.9325235948205,             mean loss domain = 331.4177509960644
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 42 | Time: 5m 34s
# step 42,             mean loss coil = 689.4571342060273,             mean loss domain = 320.4581557901148
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 43 | Time: 5m 34s
# step 43,             mean loss coil = 718.5277943534647,             mean loss domain = 330.66830805406215
# Shape: X_d:(16, 629, 4), X_c:(16, 382, 4), X_print:(1011, 4)
# Shape: Y_d:(16, 629, 1), Y_c:(16, 382, 1), Y_print:(1011, 1)
# Shape: y_pred_domain:(16, 629, 1), y_pred_coil:(16, 382, 1), y_pred:(1011, 1)
# Epoch: 44 | Time: 5m 34s
# step 44,             mean loss coil = 728.8173952561649,             mean loss domain = 338.06281194839886
# Shape: X_d:(16, 650, 4), X_c:(16, 406, 4), X_print:(1056, 4)
# Shape: Y_d:(16, 650, 1), Y_c:(16, 406, 1), Y_print:(1056, 1)
# Shape: y_pred_domain:(16, 650, 1), y_pred_coil:(16, 406, 1), y_pred:(1056, 1)
# Epoch: 45 | Time: 5m 33s
# step 45,             mean loss coil = 726.0317492561544,             mean loss domain = 337.61131896564666
# Shape: X_d:(16, 650, 4), X_c:(16, 406, 4), X_print:(1056, 4)
# Shape: Y_d:(16, 650, 1), Y_c:(16, 406, 1), Y_print:(1056, 1)
# Shape: y_pred_domain:(16, 650, 1), y_pred_coil:(16, 406, 1), y_pred:(1056, 1)
# Epoch: 46 | Time: 5m 34s
# step 46,             mean loss coil = 739.3977040785519,             mean loss domain = 343.4955720544499
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 47 | Time: 5m 35s
# step 47,             mean loss coil = 709.1949308670778,             mean loss domain = 328.8886338300246
# Shape: X_d:(16, 651, 4), X_c:(16, 407, 4), X_print:(1058, 4)
# Shape: Y_d:(16, 651, 1), Y_c:(16, 407, 1), Y_print:(1058, 1)
# Shape: y_pred_domain:(16, 651, 1), y_pred_coil:(16, 407, 1), y_pred:(1058, 1)
# Epoch: 48 | Time: 5m 42s
# step 48,             mean loss coil = 679.2153933927974,             mean loss domain = 318.59568526528096
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 49 | Time: 6m 43s
# step 49,             mean loss coil = 697.7036831289689,             mean loss domain = 323.3431510415307
# Shape: X_d:(16, 655, 4), X_c:(16, 411, 4), X_print:(1066, 4)
# Shape: Y_d:(16, 655, 1), Y_c:(16, 411, 1), Y_print:(1066, 1)
# Shape: y_pred_domain:(16, 655, 1), y_pred_coil:(16, 411, 1), y_pred:(1066, 1)
# Epoch: 50 | Time: 6m 7s
# step 50,             mean loss coil = 699.4999547948174,             mean loss domain = 325.2699027341955
# Shape: X_d:(16, 652, 4), X_c:(16, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(16, 652, 1), Y_c:(16, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(16, 652, 1), y_pred_coil:(16, 408, 1), y_pred:(1060, 1)
# Epoch: 01 | Time: 3m 0s
# step 1,             mean loss coil = 199.20925270613805,             mean loss domain = 733.7173607939033
# Shape: X_d:(32, 684, 4), X_c:(32, 444, 4), X_print:(1128, 4)
# Shape: Y_d:(32, 684, 1), Y_c:(32, 444, 1), Y_print:(1128, 1)
# Shape: y_pred_domain:(32, 684, 1), y_pred_coil:(32, 444, 1), y_pred:(1128, 1)
# Epoch: 02 | Time: 3m 0s
# step 2,             mean loss coil = 52.39951734389028,             mean loss domain = 670.7276894354051
# Shape: X_d:(32, 655, 4), X_c:(32, 411, 4), X_print:(1066, 4)
# Shape: Y_d:(32, 655, 1), Y_c:(32, 411, 1), Y_print:(1066, 1)
# Shape: y_pred_domain:(32, 655, 1), y_pred_coil:(32, 411, 1), y_pred:(1066, 1)
# Epoch: 03 | Time: 3m 3s
# step 3,             mean loss coil = 47.56190857323267,             mean loss domain = 618.6207858670142
# Shape: X_d:(32, 686, 4), X_c:(32, 456, 4), X_print:(1142, 4)
# Shape: Y_d:(32, 686, 1), Y_c:(32, 456, 1), Y_print:(1142, 1)
# Shape: y_pred_domain:(32, 686, 1), y_pred_coil:(32, 456, 1), y_pred:(1142, 1)
# Epoch: 04 | Time: 3m 5s
# step 4,             mean loss coil = 37.37584056392793,             mean loss domain = 200.74500848913706
# Shape: X_d:(32, 672, 4), X_c:(32, 436, 4), X_print:(1108, 4)
# Shape: Y_d:(32, 672, 1), Y_c:(32, 436, 1), Y_print:(1108, 1)
# Shape: y_pred_domain:(32, 672, 1), y_pred_coil:(32, 436, 1), y_pred:(1108, 1)
# Epoch: 05 | Time: 3m 3s
# step 5,             mean loss coil = 34.67094405492147,             mean loss domain = 196.71931908720282
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
# Epoch: 06 | Time: 3m 4s
# step 6,             mean loss coil = 37.425129130322446,             mean loss domain = 181.05951608637326
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
# Epoch: 07 | Time: 3m 1s
# step 7,             mean loss coil = 31.643388836614548,             mean loss domain = 174.11702051470357
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
# Epoch: 08 | Time: 2m 58s
# step 8,             mean loss coil = 32.76802018252752,             mean loss domain = 170.44427777362125
# Shape: X_d:(32, 663, 4), X_c:(32, 421, 4), X_print:(1084, 4)
# Shape: Y_d:(32, 663, 1), Y_c:(32, 421, 1), Y_print:(1084, 1)
# Shape: y_pred_domain:(32, 663, 1), y_pred_coil:(32, 421, 1), y_pred:(1084, 1)
# Epoch: 09 | Time: 3m 2s
# step 9,             mean loss coil = 32.95657037663204,             mean loss domain = 176.33979799414195
# Shape: X_d:(32, 684, 4), X_c:(32, 444, 4), X_print:(1128, 4)
# Shape: Y_d:(32, 684, 1), Y_c:(32, 444, 1), Y_print:(1128, 1)
# Shape: y_pred_domain:(32, 684, 1), y_pred_coil:(32, 444, 1), y_pred:(1128, 1)
# Epoch: 10 | Time: 3m 1s
# step 10,             mean loss coil = 27.368180568500232,             mean loss domain = 174.91527348179972
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
# Epoch: 11 | Time: 2m 59s
# step 11,             mean loss coil = 27.280435014796513,             mean loss domain = 173.12248266896893
# Shape: X_d:(32, 693, 4), X_c:(32, 454, 4), X_print:(1147, 4)
# Shape: Y_d:(32, 693, 1), Y_c:(32, 454, 1), Y_print:(1147, 1)
# Shape: y_pred_domain:(32, 693, 1), y_pred_coil:(32, 454, 1), y_pred:(1147, 1)
# Epoch: 12 | Time: 3m 5s
# step 12,             mean loss coil = 24.06628365542299,             mean loss domain = 182.20971408967048
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
# Epoch: 13 | Time: 3m 51s
# step 13,             mean loss coil = 25.54345541743822,             mean loss domain = 168.8413508630568
# Shape: X_d:(32, 707, 4), X_c:(32, 477, 4), X_print:(1184, 4)
# Shape: Y_d:(32, 707, 1), Y_c:(32, 477, 1), Y_print:(1184, 1)
# Shape: y_pred_domain:(32, 707, 1), y_pred_coil:(32, 477, 1), y_pred:(1184, 1)
# Epoch: 14 | Time: 3m 10s
# step 14,             mean loss coil = 22.569298193018923,             mean loss domain = 180.75644540274016
# Shape: X_d:(32, 681, 4), X_c:(32, 449, 4), X_print:(1130, 4)
# Shape: Y_d:(32, 681, 1), Y_c:(32, 449, 1), Y_print:(1130, 1)
# Shape: y_pred_domain:(32, 681, 1), y_pred_coil:(32, 449, 1), y_pred:(1130, 1)
# Epoch: 15 | Time: 2m 55s
# step 15,             mean loss coil = 22.260969095332648,             mean loss domain = 170.66908592306157
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
# Epoch: 16 | Time: 3m 0s
# step 16,             mean loss coil = 20.905086081515076,             mean loss domain = 171.94860911625688
# Shape: X_d:(32, 653, 4), X_c:(32, 409, 4), X_print:(1062, 4)
# Shape: Y_d:(32, 653, 1), Y_c:(32, 409, 1), Y_print:(1062, 1)
# Shape: y_pred_domain:(32, 653, 1), y_pred_coil:(32, 409, 1), y_pred:(1062, 1)
# Epoch: 17 | Time: 2m 59s
# step 17,             mean loss coil = 22.435142486326157,             mean loss domain = 173.46060836956065
# Shape: X_d:(32, 661, 4), X_c:(32, 425, 4), X_print:(1086, 4)
# Shape: Y_d:(32, 661, 1), Y_c:(32, 425, 1), Y_print:(1086, 1)
# Shape: y_pred_domain:(32, 661, 1), y_pred_coil:(32, 425, 1), y_pred:(1086, 1)
# Epoch: 18 | Time: 3m 2s
# step 18,             mean loss coil = 22.850291439281996,             mean loss domain = 160.86394037226194
# Shape: X_d:(32, 674, 4), X_c:(32, 432, 4), X_print:(1106, 4)
# Shape: Y_d:(32, 674, 1), Y_c:(32, 432, 1), Y_print:(1106, 1)
# Shape: y_pred_domain:(32, 674, 1), y_pred_coil:(32, 432, 1), y_pred:(1106, 1)
# Epoch: 19 | Time: 3m 3s
# step 19,             mean loss coil = 21.458090082291633,             mean loss domain = 163.40782091694493
# Shape: X_d:(32, 634, 4), X_c:(32, 387, 4), X_print:(1021, 4)
# Shape: Y_d:(32, 634, 1), Y_c:(32, 387, 1), Y_print:(1021, 1)
# Shape: y_pred_domain:(32, 634, 1), y_pred_coil:(32, 387, 1), y_pred:(1021, 1)
# Epoch: 20 | Time: 3m 1s
# step 20,             mean loss coil = 20.527111076539562,             mean loss domain = 153.74045804751816
# Shape: X_d:(32, 655, 4), X_c:(32, 411, 4), X_print:(1066, 4)
# Shape: Y_d:(32, 655, 1), Y_c:(32, 411, 1), Y_print:(1066, 1)
# Shape: y_pred_domain:(32, 655, 1), y_pred_coil:(32, 411, 1), y_pred:(1066, 1)
# Epoch: 21 | Time: 3m 2s
# step 21,             mean loss coil = 18.92758298048409,             mean loss domain = 159.6020433364376
# Shape: X_d:(32, 635, 4), X_c:(32, 388, 4), X_print:(1023, 4)
# Shape: Y_d:(32, 635, 1), Y_c:(32, 388, 1), Y_print:(1023, 1)
# Shape: y_pred_domain:(32, 635, 1), y_pred_coil:(32, 388, 1), y_pred:(1023, 1)
# Epoch: 22 | Time: 3m 1s
# step 22,             mean loss coil = 21.78398689659693,             mean loss domain = 160.4334136183544
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
# Epoch: 23 | Time: 3m 4s
# step 23,             mean loss coil = 18.64733282084106,             mean loss domain = 162.16824794071977
# Shape: X_d:(32, 663, 4), X_c:(32, 421, 4), X_print:(1084, 4)
# Shape: Y_d:(32, 663, 1), Y_c:(32, 421, 1), Y_print:(1084, 1)
# Shape: y_pred_domain:(32, 663, 1), y_pred_coil:(32, 421, 1), y_pred:(1084, 1)
# Epoch: 24 | Time: 3m 3s
# step 24,             mean loss coil = 16.033719749860865,             mean loss domain = 151.57542714764995
# Shape: X_d:(32, 672, 4), X_c:(32, 431, 4), X_print:(1103, 4)
# Shape: Y_d:(32, 672, 1), Y_c:(32, 431, 1), Y_print:(1103, 1)
# Shape: y_pred_domain:(32, 672, 1), y_pred_coil:(32, 431, 1), y_pred:(1103, 1)
# Epoch: 25 | Time: 3m 1s
# step 25,             mean loss coil = 19.286972708599542,             mean loss domain = 156.96214956878333
# Shape: X_d:(32, 703, 4), X_c:(32, 463, 4), X_print:(1166, 4)
# Shape: Y_d:(32, 703, 1), Y_c:(32, 463, 1), Y_print:(1166, 1)
# Shape: y_pred_domain:(32, 703, 1), y_pred_coil:(32, 463, 1), y_pred:(1166, 1)
# Epoch: 26 | Time: 3m 0s
# step 26,             mean loss coil = 17.02831211141361,             mean loss domain = 151.70738917525097
# Shape: X_d:(32, 703, 4), X_c:(32, 463, 4), X_print:(1166, 4)
# Shape: Y_d:(32, 703, 1), Y_c:(32, 463, 1), Y_print:(1166, 1)
# Shape: y_pred_domain:(32, 703, 1), y_pred_coil:(32, 463, 1), y_pred:(1166, 1)
# Epoch: 27 | Time: 3m 1s
# step 27,             mean loss coil = 18.575106384933637,             mean loss domain = 155.15004063678043
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
# Epoch: 28 | Time: 3m 0s
# step 28,             mean loss coil = 16.73914812457177,             mean loss domain = 157.60025781200778
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
# Epoch: 29 | Time: 3m 1s
# step 29,             mean loss coil = 15.46040407688387,             mean loss domain = 157.41236344204154
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
# Epoch: 30 | Time: 3m 1s
# step 30,             mean loss coil = 15.30701898503047,             mean loss domain = 157.34897271023002
# Shape: X_d:(32, 681, 4), X_c:(32, 438, 4), X_print:(1119, 4)
# Shape: Y_d:(32, 681, 1), Y_c:(32, 438, 1), Y_print:(1119, 1)
# Shape: y_pred_domain:(32, 681, 1), y_pred_coil:(32, 438, 1), y_pred:(1119, 1)
# Epoch: 31 | Time: 3m 1s
# step 31,             mean loss coil = 15.31999231666647,             mean loss domain = 156.47599761716782
# Shape: X_d:(32, 663, 4), X_c:(32, 421, 4), X_print:(1084, 4)
# Shape: Y_d:(32, 663, 1), Y_c:(32, 421, 1), Y_print:(1084, 1)
# Shape: y_pred_domain:(32, 663, 1), y_pred_coil:(32, 421, 1), y_pred:(1084, 1)
# Epoch: 32 | Time: 3m 4s
# step 32,             mean loss coil = 18.752199072991647,             mean loss domain = 154.78772116220125
# Shape: X_d:(32, 663, 4), X_c:(32, 421, 4), X_print:(1084, 4)
# Shape: Y_d:(32, 663, 1), Y_c:(32, 421, 1), Y_print:(1084, 1)
# Shape: y_pred_domain:(32, 663, 1), y_pred_coil:(32, 421, 1), y_pred:(1084, 1)
# Epoch: 33 | Time: 3m 6s
# step 33,             mean loss coil = 17.631011507844413,             mean loss domain = 154.88088876457624
# Shape: X_d:(32, 683, 4), X_c:(32, 443, 4), X_print:(1126, 4)
# Shape: Y_d:(32, 683, 1), Y_c:(32, 443, 1), Y_print:(1126, 1)
# Shape: y_pred_domain:(32, 683, 1), y_pred_coil:(32, 443, 1), y_pred:(1126, 1)
# Epoch: 34 | Time: 3m 5s
# step 34,             mean loss coil = 17.45548677059912,             mean loss domain = 160.17339958683138
# Shape: X_d:(32, 683, 4), X_c:(32, 440, 4), X_print:(1123, 4)
# Shape: Y_d:(32, 683, 1), Y_c:(32, 440, 1), Y_print:(1123, 1)
# Shape: y_pred_domain:(32, 683, 1), y_pred_coil:(32, 440, 1), y_pred:(1123, 1)
# Epoch: 35 | Time: 3m 8s
# step 35,             mean loss coil = 16.220148464684847,             mean loss domain = 159.43851038204727
# Shape: X_d:(32, 652, 4), X_c:(32, 408, 4), X_print:(1060, 4)
# Shape: Y_d:(32, 652, 1), Y_c:(32, 408, 1), Y_print:(1060, 1)
# Shape: y_pred_domain:(32, 652, 1), y_pred_coil:(32, 408, 1), y_pred:(1060, 1)
